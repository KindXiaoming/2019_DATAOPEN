# %%
###########This notebook looks up tables from mortality and health_indicator

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data_dir = "../Data/Mortality/mortal_a.csv"
data = pd.read_csv(data_dir)
cc = data["country_code"]

# %%
year = [str(i) for i in range(2009,2016)]

# %%
#data_ = data[year]
# Out:
#     country_code  1988  1989  1990  1991  1992  1993  1994  1995  1996  ...    \
# 0            ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1            ANT   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2            ARG   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3            ARM   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4            ATG   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5            AUS   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6            AUT   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7            AZE   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8            BEL   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9            BGR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10           BHR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
plt.hist(data_.isna().sum(axis=1),bins=7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-1e7a72278d1d> in <module>()
# ----> 1 plt.hist(data_.isna().sum(axis=1),bins=7)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9567                                       skipna=skipna, min_count=min_count)
#    9568         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9569                             numeric_only=numeric_only, min_count=min_count)
#    9570
#    9571     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3211         if isinstance(delegate, np.ndarray):
#    3212             # Validate that 'axis' is consistent with Series's single axis.
# ...

# %%
#data[data_.isna().sum(axis=1)<=0].shape
mort = data[data_.isna().sum(axis=1)!=7]["country_code"]

# %%
data_dir = "../Data/Consumption/consumption_feature.csv"
con_fea = pd.read_csv(data_dir)

# %%
cc2 = con_fea["country_code"]
len(set(mort)&set(cc2))
# Out:
# 16

# %%
#data_.iloc[data_.isna().sum(axis=1)!=7]
try:
    data_ = data_.iloc[mort.index].sum(axis=1)/(7-data_[data_.isna().sum(axis=1)!=7].isna().sum(axis=1))
except:
    pass

av_mort = {"country_code":mort, "mort":data_}
df = pd.DataFrame(av_mort)
df.to_csv("../Data/Mortality/available_average_mor.csv")

# %%
av = pd.read_csv("../Data/Mortality/available_average_mor.csv")

# %%
common = set(av["country_code"])&set(cc2)
common
av["country_code"].shape
cc2.shape
# Out:
# (90,)

# %%
data_dir = "../Data/Mortality/mortal_country_codes.txt"
with open(data_dir) as f:
    mo = f.read().splitlines()
len(set(mo)&set(cc2))
# Out:
# 24

# %%
av_s = av[av["country_code"].isin(common)]
av_s = av_s.sort_values(by=['country_code'])
cf_s = con_fea[con_fea["country_code"].isin(common)]
cf_s = cf_s.sort_values(by=['country_code'])

# %%
inputs = cf_s.as_matrix()[:,2:]
outputs = av_s["mort"].as_matrix()
# Out:
# C:\Users\surface\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\surface\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
plt.scatter(inputs[:,3],inputs[:,2],c=np.log(outputs))
plt.colorbar()

# %%
for i in range(5):
    for j in range(5):
        plt.scatter(inputs[:,i],inputs[:,j])
        plt.title(str(i)+","+str(j))
        plt.show()

# %%
for i in range(5):
    plt.scatter(inputs[:,i],np.log(outputs))
    plt.show()

# %%
cc2.to_csv("../Data/Consumption/consumption_country_names.csv")
